# %% [markdown]
# # Milestone 2
# ## Introduction
# - Name: Izzan Dienurrahman
# - Batch: HCK-003
#
# ## Objective
# - Membuat model inference
#
# ## Problem Statements
# - Membuat atau meload data inference
# - Meload model yang telah di save sebelumnya
# - Melakukan inference pada data baru

# %% [markdown]
# # Import Library

# %%
# import library yang dibutuhkan
import pandas as pd
import numpy  as np
import joblib
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %% [markdown]
# # Load Model

# %%
# load model, encoder, scaler, dan selected features
with open('catb_randcv.pkl','rb') as file_1:
    catb_randcv = joblib.load(file_1)

# %% [markdown]
# # Data Loading

# %%
data_infer = pd.read_csv('infer.csv')

# %%
data_infer.head()
# Out:
#    Gender   Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male  Loyal Customer   44  Business travel  Business             3306
# 1  Female  Loyal Customer   30  Business travel  Business             2979
# 2    Male  Loyal Customer   40  Business travel  Business              449
# 3  Female  Loyal Customer   50  Business travel  Business             1090
# 4    Male  Loyal Customer   58  Business travel  Business             2116
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      2                                  2
# 1                      2                                  4
# 2                      2                                  2
# 3                      3                                  3
# 4                      2                                  2
#
#    Ease of Online booking  Gate location  ...  Seat comfort  \
# 0                       2              2  ...             4
# 1                       4              4  ...             2
# 2                       2              2  ...             5
# 3                       3              3  ...             5
# 4                       2              2  ...             4
#
#    Inflight entertainment  On-board service  Leg room service  \
# 0                       4                 4                 4
# 1                       2                 4                 1
# 2                       4                 4                 4
# 3                       4                 4                 4
# 4                       4                 4                 4
#
#    Baggage handling  Checkin service  Inflight service  Cleanliness  \
# 0                 4                3                 4            5
# 1                 4                1                 4            2
# 2                 4                5                 4            4
# 3                 4                5                 4            3
# 4                 5                3                 4            4
#
#    Departure Delay in Minutes  Arrival Delay in Minutes
# 0                           0                       0.0
# 1                           0                       0.0
# 2                           1                      16.0
# 3                         109                      97.0
# 4                          97                      73.0
#
# [5 rows x 22 columns]

# %% [markdown]
# # Model Inference

# %%
# predict result with catboost
pred_catboost = catb_randcv.predict(data_infer)

# %%
# show data infer + prediction
data_infer['pred_target_catb'] = pred_catboost
data_infer
# Out:
#    Gender      Customer Type  Age   Type of Travel     Class  Flight Distance  \
# 0    Male     Loyal Customer   44  Business travel  Business             3306
# 1  Female     Loyal Customer   30  Business travel  Business             2979
# 2    Male     Loyal Customer   40  Business travel  Business              449
# 3  Female     Loyal Customer   50  Business travel  Business             1090
# 4    Male     Loyal Customer   58  Business travel  Business             2116
# 5    Male  disloyal Customer   41  Business travel  Business              402
# 6    Male  disloyal Customer   29  Business travel       Eco             1048
# 7    Male     Loyal Customer   49  Business travel       Eco              125
# 8  Female     Loyal Customer   56  Business travel       Eco             1189
# 9    Male     Loyal Customer   31  Business travel       Eco             2599
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      2                                  2
# 1                      2                                  4
# 2                      2                                  2
# 3                      3                                  3
# 4                      2                                  2
# 5                      5                                  5
# 6                      2                                  3
# 7                      2                                  4
# 8                      4                                  1
# 9                      0                                  0
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       2              2  ...                       4
# 1                       4              4  ...                       2
# 2                       2              2  ...                       4
# 3                       3              3  ...                       4
# 4                       2              2  ...                       4
# 5                       5              3  ...                       2
# 6                       3              4  ...                       5
# 7                       4              4  ...                       2
# 8                       5              1  ...                       4
# 9                       0              5  ...                       3
#
#    On-board service  Leg room service  Baggage handling  Checkin service  \
# 0                 4                 4                 4                3
# 1                 4                 1                 4                1
# 2                 4                 4                 4                5
# 3                 4                 4                 4                5
# 4                 4                 4                 5                3
# 5                 3                 4                 4                5
# 6                 4                 5                 3                4
# 7                 1                 4                 3                2
# 8                 4                 4                 4                4
# 9                 5                 1                 5                2
#
#    Inflight service  Cleanliness  Departure Delay in Minutes  \
# 0                 4            5                           0
# 1                 4            2                           0
# 2                 4            4                           1
# 3                 4            3                         109
# 4                 4            4                          97
# 5                 4            2                          76
# 6                 3            5                           0
# 7                 4            2                           0
# 8                 4            1                          92
# 9                 5            3                           0
#
#    Arrival Delay in Minutes         pred_target_catb
# 0                       0.0                satisfied
# 1                       0.0  neutral or dissatisfied
# 2                      16.0                satisfied
# 3                      97.0                satisfied
# 4                      73.0                satisfied
# 5                      95.0                satisfied
# 6                      11.0  neutral or dissatisfied
# 7                       0.0  neutral or dissatisfied
# 8                      92.0                satisfied
# 9                       0.0                satisfied
#
# [10 rows x 23 columns]
